# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('data.csv')
data
data=data.iloc[:,[1,3,4]]
data.columns = ['日期', '測項', '18']
plt.plot(data['18'])
plt.axhline(y=35,color='#d62728')
data
dangerous=[]
counter=0
for i in range(358):
    if data['18'][i]>35:
        dangerous.append(data['18'][i])
        counter+=1
avge=np.mean(data['18'])
maxnum=np.max(data['18'])
minnum=np.min(data['18'])
maxdate=data[data['18']==maxnum]
mindate=data[data['18']==minnum]
x=maxdate['日期']
y=mindate['日期']        
print('pm2.5最高的日子:',x)
print('pm2.5最高:',maxnum)
print('pm2.5最低的日子:',y,'pm2.5:',minnum)
print('pm2.5最低:',minnum)
print('超標天數:',len(dangerous))
# Out:
# pm2.5最高的日子: 330    2018/12/3
# Name: 日期, dtype: object
# pm2.5最高: 50
# pm2.5最低的日子: 250    2018/9/14
# Name: 日期, dtype: object pm2.5: 1
# pm2.5最低: 1
# 超標天數: 11
